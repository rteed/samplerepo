# %%
# %cd /content/drive/MyDrive/major_project/gitpushtest
# Out:
# /content/drive/MyDrive/major_project/gitpushtest

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/major_project/gitpushtest/.git/

# %%
# !git add .

# %%
# !git commit -m "commit"
# Out:
# [master (root-commit) 09bb09a] commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 githu.ipynb

# %%
# !git config --global user.email "rk.rakredy2@gmail.com"

# %%
# !git config --global user.name "rteed"

# %%
# !git remote add origin https://rteed:rakrteed2@github.com/rteed/samplerepo.git

# %%
# !git remote rm origin

# %%
# !git remote -v
# Out:
# origin	https://rteed:rakrteed2@github.com/rteed/samplerepo.git (fetch)
# origin	https://rteed:rakrteed2@github.com/rteed/samplerepo.git (push)

# %%
# !git push -u origin master
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 967 bytes | 161.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/rteed/samplerepo.git
#  * [new branch]      master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.
